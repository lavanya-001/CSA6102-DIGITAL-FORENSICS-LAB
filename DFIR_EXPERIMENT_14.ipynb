# %% [markdown]
# <a href="https://colab.research.google.com/github/lavanya-001/CSA6102-DIGITAL-FORENSICS-LAB/blob/main/DFIR_EXPERIMENT_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
subject = "Verify Your Account Immediately"

print("Subject:", subject)
print("\nObservation:")
print("- Uses urgent language.")
print("- Tries to create fear and pressure.")
print("- Common phishing technique.")
# Out:
# Subject: Verify Your Account Immediately
#
# Observation:
# - Uses urgent language.
# - Tries to create fear and pressure.
# - Common phishing technique.
