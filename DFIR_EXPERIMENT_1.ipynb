# %%
import os
import time

# Create a sample file
filename = "evidence.txt"

with open(filename, "w") as file:
    file.write("Original Evidence")

print("File created successfully.")
# Out:
# File created successfully.

# %%
import os
import time

filename = "evidence.txt"

print("Before Modification")

print("Access Time :", time.ctime(os.path.getatime(filename)))
print("Modification Time :", time.ctime(os.path.getmtime(filename)))
print("Creation Time :", time.ctime(os.path.getctime(filename)))
# Out:
# Before Modification
# Access Time : Thu Jul 16 04:57:36 2026
# Modification Time : Thu Jul 16 04:57:26 2026
# Creation Time : Thu Jul 16 04:57:26 2026

# %%
import time

print("Waiting for 5 seconds...")
time.sleep(5)
# Out:
# Waiting for 5 seconds...

# %%
filename = "evidence.txt"

with open(filename, "a") as file:
    file.write("\nModified Evidence")

print("File Modified")
# Out:
# File Modified

# %%
import os
import time

filename = "evidence.txt"

print("After Modification")

print("Access Time :", time.ctime(os.path.getatime(filename)))
print("Modification Time :", time.ctime(os.path.getmtime(filename)))
print("Creation Time :", time.ctime(os.path.getctime(filename)))
# Out:
# After Modification
# Access Time : Thu Jul 16 04:59:04 2026
# Modification Time : Thu Jul 16 04:58:54 2026
# Creation Time : Thu Jul 16 04:58:54 2026

# %%
with open("evidence.txt","r") as file:
    print(file.read())
# Out:
# Original Evidence
# Modified Evidence
